# %% [markdown]
# <a href="https://colab.research.google.com/github/arpit01101993/scalar_module1/blob/main/DAV3Homework.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
question1 = pd.read_csv("sales.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-6-2243909521.py in <cell line: 0>()
# ----> 1 question1 = pd.read_csv("sales.csv")
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# ...

# %%
question1.head()
# Out:
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 3  489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#            InvoiceDate  Price  Customer ID         Country
# 0  2009-12-01 07:45:00   6.95      13085.0  United Kingdom
# 1  2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 2  2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 3  2009-12-01 07:45:00   2.10      13085.0  United Kingdom
# 4  2009-12-01 07:45:00   1.25      13085.0  United Kingdom

# %%
question1['purchase_amount'] = question1['Quantity']*question1['Price']

# %%
question1.head()
# Out:
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 3  489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#            InvoiceDate  Price  Customer ID         Country  purchase_amount
# 0  2009-12-01 07:45:00   6.95      13085.0  United Kingdom             83.4
# 1  2009-12-01 07:45:00   6.75      13085.0  United Kingdom             81.0
# 2  2009-12-01 07:45:00   6.75      13085.0  United Kingdom             81.0
# 3  2009-12-01 07:45:00   2.10      13085.0  United Kingdom            100.8
# 4  2009-12-01 07:45:00   1.25      13085.0  United Kingdom             30.0

# %%
max_row = question1.loc[question1['purchase_amount'].idxmax()]

# %%
print(max_row)
# Out:
# Invoice                                 581483
# StockCode                                23843
# Description        PAPER CRAFT , LITTLE BIRDIE
# Quantity                                 80995
# InvoiceDate                2011-12-09 09:15:00
# Price                                     2.08
# Customer ID                            16446.0
# Country                         United Kingdom
# purchase_amount                       168469.6
# Name: 1065882, dtype: object

# %%
df = {
    "Name": ["Jim","Carry","Chris","Moris"],
    "Gender": ["M","F","M","M"],
    "Profession": ["Athelete","Teacher","Cricketer","Actor"]
}

# %%
pd_df = pd.DataFrame(df)

# %%
pd_df.iloc[:2,:2]
# Out:
#     Name Gender
# 0    Jim      M
# 1  Carry      F

# %%
pd_df.loc[:2, "Name":"Profession"]
# Out:
#     Name Gender Profession
# 0    Jim      M   Athelete
# 1  Carry      F    Teacher
# 2  Chris      M  Cricketer

# %%
titanic = pd.read_csv("titanic.csv")

# %%
titanic.head(10)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0         1       3  female  26.0      0      0   7.9250        S   Third
# 1         1       1  female  38.0      1      0  71.2833        C   First
# 2         1       3  female  26.0      0      0   7.9250        S   Third
# 3         0       3    male   NaN      0      0   8.4583        Q   Third
# 4         1       2  female  14.0      1      0  30.0708        C  Second
# 5         0       3    male   NaN      0      0   8.4583        Q   Third
# 6         0       1    male  54.0      0      0  51.8625        S   First
# 7         1       1  female  38.0      1      0  71.2833        C   First
# 8         1       3  female  27.0      0      2  11.1333        S   Third
# 9         1       2  female  14.0      1      0  30.0708        C  Second
#
#    adult_male  embark_town  pclass_1    price  gender
# 0       False  Southampton         3   7.9250  female
# ...

# %%
titanic.T.drop_duplicates(keep = 'first')
# Out:
#                        0          1            2           3          4  \
# survived               1          1            1           0          1
# pclass                 3          1            3           3          2
# sex               female     female       female        male     female
# age                 26.0       38.0         26.0         NaN       14.0
# sibsp                  0          1            0           0          1
# parch                  0          0            0           0          0
# fare               7.925    71.2833        7.925      8.4583    30.0708
# embarked               S          C            S           Q          C
# class              Third      First        Third       Third     Second
# adult_male         False      False        False        True      False
# embark_town  Southampton  Cherbourg  Southampton  Queenstown  Cherbourg
#
#                       5            6          7            8          9
# ...

# %%
titanic.drop_duplicates(keep ="first")
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0         1       3  female  26.0      0      0   7.9250        S   Third
# 1         1       1  female  38.0      1      0  71.2833        C   First
# 3         0       3    male   NaN      0      0   8.4583        Q   Third
# 4         1       2  female  14.0      1      0  30.0708        C  Second
# 6         0       1    male  54.0      0      0  51.8625        S   First
# 8         1       3  female  27.0      0      2  11.1333        S   Third
#
#    adult_male  embark_town  pclass_1    price  gender
# 0       False  Southampton         3   7.9250  female
# 1       False    Cherbourg         1  71.2833  female
# 3        True   Queenstown         3   8.4583    male
# 4       False    Cherbourg         2  30.0708  female
# 6        True  Southampton         1  51.8625    male
# 8       False  Southampton         3  11.1333  female

# %%
titanic.drop_duplicates(keep ="last")
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 2         1       3  female  26.0      0      0   7.9250        S   Third
# 5         0       3    male   NaN      0      0   8.4583        Q   Third
# 6         0       1    male  54.0      0      0  51.8625        S   First
# 7         1       1  female  38.0      1      0  71.2833        C   First
# 8         1       3  female  27.0      0      2  11.1333        S   Third
# 9         1       2  female  14.0      1      0  30.0708        C  Second
#
#    adult_male  embark_town  pclass_1    price  gender
# 2       False  Southampton         3   7.9250  female
# 5        True   Queenstown         3   8.4583    male
# 6        True  Southampton         1  51.8625    male
# 7       False    Cherbourg         1  71.2833  female
# 8       False  Southampton         3  11.1333  female
# 9       False    Cherbourg         2  30.0708  female

# %%
df= {'name':["Sam","Roma","Mark","Ram","Dev"], "profession":['dev','mle','Data scientist','sde','mle'],"gender":['male','female','male','male','male'], "age":[21,20,25,50,30],"review":['No comments','hardworker','need improvement','Can be improved','Scope of improvement'],"rating":[10,5,7,6,14]}

# %%
input_df = pd.DataFrame(df)

# %%
input_df
# Out:
#    name      profession  gender  age                review  rating
# 0   Sam             dev    male   21           No comments      10
# 1  Roma             mle  female   20            hardworker       5
# 2  Mark  Data scientist    male   25      need improvement       7
# 3   Ram             sde    male   50       Can be improved       6
# 4   Dev             mle    male   30  Scope of improvement      14

# %%
new_df = input_df[input_df['rating'] >= 6]

# %%
new_df[['profession','gender','age']]
# Out:
#        profession gender  age
# 0             dev   male   21
# 2  Data scientist   male   25
# 3             sde   male   50
# 4             mle   male   30

# %%
import pandas as pd
df = pd.DataFrame({'City\tState': ["Kolkata\tWest Bengal", "Chennai\tTamil Nadu", "Hyderabad\tTelengana", "Bangalore\tKarnataka"]})

# %%
df.head()
# Out:
#             City\tState
# 0  Kolkata\tWest Bengal
# 1   Chennai\tTamil Nadu
# 2  Hyderabad\tTelengana
# 3  Bangalore\tKarnataka

# %%
df[['City', 'State']] = df['City\tState'].str.split('\t', n=1, expand=True)

# %%
df.head()
# Out:
#             City\tState       City        State
# 0  Kolkata\tWest Bengal    Kolkata  West Bengal
# 1   Chennai\tTamil Nadu    Chennai   Tamil Nadu
# 2  Hyderabad\tTelengana  Hyderabad    Telengana
# 3  Bangalore\tKarnataka  Bangalore    Karnataka

# %%
df = pd.DataFrame([[1, "Ram", "IT"], [2, "Shyam", "Ops"]], columns = ["emp_id", "name", "dept"])

# %%
df.head()
# Out:
#    emp_id   name dept
# 0       1    Ram   IT
# 1       2  Shyam  Ops

# %%
df = pd.DataFrame([[1, 2], ["Ram", "Shyam"], ["IT", "Ops"]], columns = ["emp_id", "name", "dept"])
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/internals/construction.py in _finalize_columns_and_data(content, columns, dtype)
#     938     try:
# --> 939         columns = _validate_or_indexify_columns(contents, columns)
#     940     except AssertionError as err:
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/internals/construction.py in _validate_or_indexify_columns(content, columns)
#     985             # caller's responsibility to check for this...
# --> 986             raise AssertionError(
#     987                 f"{len(columns)} columns passed, passed data had "
#
# AssertionError: 3 columns passed, passed data had 2 columns
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# ...

# %%
df = pd.DataFrame([1, "Ram", "IT"], columns = ["emp_id", "name", "dept"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-23-944441965.py in <cell line: 0>()
# ----> 1 df = pd.DataFrame([1, "Ram", "IT"], columns = ["emp_id", "name", "dept"])
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     865                     )
#     866                 else:
# --> 867                     mgr = ndarray_to_mgr(
#     868                         data,
#     869                         index,
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/internals/construction.py in ndarray_to_mgr(values, index, columns, dtype, copy, typ)
#     334     )
#     335
# --> 336     _check_values_indices_shape_match(values, index, columns)
#     337
#     338     if typ == "array":
#
# ...

# %%
df = pd.DataFrame({'emp_id':[1, 2], 'name': ['Ram', 'Shyam'], 'dept':['IT', 'Ops']})

# %%
df = {
    "name": ["a","b","c"],
    "age": [12,15,18]
}

# %%
adddf = {
    "name": ["d","e","f"],
    "age": [13,16,19]
}

# %%
df1 = pd.DataFrame(df)
data = pd.DataFrame(adddf)

# %%
added_df = pd.concat([df1,data],axis=0, ignore_index=True)

# %%
adddf
# Out:
# {'name': ['d', 'e', 'f'], 'age': [13, 16, 19]}

# %%
added_df
# Out:
#   name  age
# 0    a   12
# 1    b   15
# 2    c   18
# 3    d   13
# 4    e   16
# 5    f   19

# %%
added_df.drop(4, inplace=True)

# %%
added_df
# Out:
#   name  age
# 0    a   12
# 1    b   15
# 2    c   18
# 3    d   13
# 5    f   19
