# %% [markdown]
# <a href="https://colab.research.google.com/github/arpit01101993/scalar_module1/blob/main/DAV5(My).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/101/215/original/clean_amazon_data.csv
# Out:
# --2025-06-30 15:32:38--  https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/101/215/original/clean_amazon_data.csv
# Resolving d2beiqkhq929f0.cloudfront.net (d2beiqkhq929f0.cloudfront.net)... 3.169.201.143, 3.169.201.165, 3.169.201.14, ...
# Connecting to d2beiqkhq929f0.cloudfront.net (d2beiqkhq929f0.cloudfront.net)|3.169.201.143|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6052052 (5.8M) [text/plain]
# Saving to: ‘clean_amazon_data.csv’
#
# clean_amazon_data.c 100%[===================>]   5.77M  --.-KB/s    in 0.1s
#
# 2025-06-30 15:32:39 (54.1 MB/s) - ‘clean_amazon_data.csv’ saved [6052052/6052052]

# %%
df = pd.read_csv("clean_amazon_data.csv")

# %%
import pandas as pd

# Create first DataFrame
df1 = pd.DataFrame({
    'first_name': ['Alice', 'Bob', 'Charlie','Alice'],
    'last_name': ['Smith', 'Jones', 'Brown','John'],
    'age': [25, 30, 35, 40]
})

# Create second DataFrame
df2 = pd.DataFrame({
    'first_name': ['Alice', 'Bob', 'David', 'Alice'],
    'last_name': ['Smith', 'Jones', 'Taylor', 'Alice'],
    'city': ['New York', 'Los Angeles', 'Chicago', 'Sanfrancisco']
})

# Merge on two columns: 'first_name' and 'last_name'
merged_df = pd.merge(df1, df2, on=['first_name', 'last_name'], how='left')

# %%
mean_rating = df["rating"].mean()
print(mean_rating)
# Out:
# 4.105998835177635

# %%
df["rating_filled"] = df["rating"].fillna(mean_rating)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1737 entries, 0 to 1736
# Data columns (total 30 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  1737 non-null   object
#  1   user_id                     1737 non-null   object
#  2   user_name                   1737 non-null   object
#  3   review_id                   1737 non-null   object
#  4   review_title                1737 non-null   object
#  5   review_content              1737 non-null   object
#  6   order_timestamp             1737 non-null   object
#  7   product_name                1737 non-null   object
#  8   category                    1724 non-null   object
#  9   discounted_price            1724 non-null   float64
#  10  actual_price                1729 non-null   float64
#  11  rating                      1717 non-null   float64
#  12  rating_count                1735 non-null   float64
#  13  about_product               1737 non-null   object
#  14  img_link                    1737 non-null   object
#  15  product_link                1737 non-null   object
#  16  review_title_uppercase      1737 non-null   object
#  17  calculated_discount         1716 non-null   float64
#  18  price_range                 1727 non-null   object
#  19  rating_category             1717 non-null   object
#  20  rating_filled               1737 non-null   float64
#  21  category_filled             1737 non-null   object
#  22  calculated_discount_filled  1737 non-null   float64
#  23  contains_durable            1737 non-null   bool
#  24  product_qid                 1737 non-null   int64
#  25  week_number                 1737 non-null   int64
#  26  day_name                    1737 non-null   object
#  27  year                        1737 non-null   int64
#  28  month                       1737 non-null   int64
#  29  month_year                  1737 non-null   object
# dtypes: bool(1), float64(7), int64(4), object(18)
# memory usage: 395.4+ KB

# %%
df['category'].value_counts()
# Out:
# category
# Computers&Accessories    647
# Electronics              595
# Home&Kitchen             444
# OfficeProducts            31
# MusicalInstruments         2
# HomeImprovement            2
# Toys&Games                 1
# Car&Motorbike              1
# Health&PersonalCare        1
# Name: count, dtype: int64

# %%
df['category_new'] = df['category'].fillna("Other")

# %%
df['category_new'].value_counts()
# Out:
# category_new
# Computers&Accessories    647
# Electronics              595
# Home&Kitchen             444
# OfficeProducts            31
# Other                     13
# MusicalInstruments         2
# HomeImprovement            2
# Toys&Games                 1
# Car&Motorbike              1
# Health&PersonalCare        1
# Name: count, dtype: int64

# %%
#date & time stamps

df["order_timestamp"].dtype
# Out:
# dtype('O')

# %%
df['order_time_converted'] = pd.to_datetime(df['order_timestamp'])

# %%
df['order_time_converted'].dtype
# Out:
# dtype('<M8[ns]')

# %%
df['order_time_converted'].head()
# Out:
# 0   2023-01-01 00:00:00.000000000
# 1   2023-01-01 00:00:00.000000000
# 2   2023-01-01 00:00:00.000000000
# 3   2023-01-01 05:58:01.967213114
# 4   2023-01-01 05:58:01.967213114
# Name: order_time_converted, dtype: datetime64[ns]

# %%
df['order_year'] = df['order_time_converted'].dt.year

# %%
df['order_year'].head()
# Out:
# 0    2023
# 1    2023
# 2    2023
# 3    2023
# 4    2023
# Name: order_year, dtype: int32

# %%
df['order_time_converted_format'] = pd.to_datetime(df['order_timestamp_converted'], format="%Y-%m-%d")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'order_timestamp_converted'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-19-3767199510.py in <cell line: 0>()
# ----> 1 df['order_time_converted_format'] = pd.to_datetime(df['order_timestamp_converted'], format="%Y-%m-%d")
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'order_timestamp_converted'

# %%
df['day_name'] = df['order_time_converted'].dt.day_name()

# %%
df['day_name'].head()
# Out:
# 0    Sunday
# 1    Sunday
# 2    Sunday
# 3    Sunday
# 4    Sunday
# Name: day_name, dtype: object

# %%
df['month_year'] = df['order_time_converted'].dt.strftime('%B %Y')
df['month_year'].head()
# Out:
# 0    January 2023
# 1    January 2023
# 2    January 2023
# 3    January 2023
# 4    January 2023
# Name: month_year, dtype: object

# %%
df.to_csv('clean_amazon_data1.csv', index= False)

# %%
# !wget https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/101/215/original/clean_amazon_data.csv
# Out:
# --2025-06-30 16:04:59--  https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/101/215/original/clean_amazon_data.csv
# Resolving d2beiqkhq929f0.cloudfront.net (d2beiqkhq929f0.cloudfront.net)... 3.167.84.28, 3.167.84.148, 3.167.84.9, ...
# Connecting to d2beiqkhq929f0.cloudfront.net (d2beiqkhq929f0.cloudfront.net)|3.167.84.28|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6052052 (5.8M) [text/plain]
# Saving to: ‘clean_amazon_data.csv.1’
#
# clean_amazon_data.c 100%[===================>]   5.77M  27.1MB/s    in 0.2s
#
# 2025-06-30 16:04:59 (27.1 MB/s) - ‘clean_amazon_data.csv.1’ saved [6052052/6052052]

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("clean_amazon_data.csv")
df
# Out:
#       product_id                                            user_id  \
# 0     B07JW9H4J1  AG3D6O4STAQKAY2UVGEUV46KN35Q,AHMY5CWJMMK5BJRBB...
# 1     B07JW9H4J1  AG3D6O4STAQKAY2UVGEUV46KN35Q,AHMY5CWJMMK5BJRBB...
# 2     B07JW9H4J1  AG3D6O4STAQKAY2UVGEUV46KN35Q,AHMY5CWJMMK5BJRBB...
# 3     B098NS6PVG  AECPFYFQVRUWC3KGNLJIOREFP5LQ,AGYYVPDD7YG7FYNBX...
# 4     B098NS6PVG  AECPFYFQVRUWC3KGNLJIOREFP5LQ,AGYYVPDD7YG7FYNBX...
# ...          ...                                                ...
# 1732  B08L7J3T31  AHITFY6AHALOFOHOZEOC6XBP4FEA,AFRABBODZJZQB6Z4U...
# 1733  B01M6453MB  AFG5FM3NEMOL6BNFRV2NK5FNJCHQ,AGEINTRN6Z563RMLH...
# 1734  B009P2LIL4  AGVPWCMAHYQWJOQKMUJN4DW3KM5Q,AF4Q3E66MY4SR7YQZ...
# 1735  B00J5DYCCA  AF2JQCLSCY3QJATWUNNHUSVUPNQQ,AFDMLUXC5LS5RXDJS...
# 1736  B01486F4G6  AFGW5PT3R6ZAVQR4Y5MWVAKBZAYA,AG7QNJ2SCS5VS5VYY...
#
#                                               user_name  \
# 0     Manav,Adarsh gupta,Sundeep,S.Sayeed Ahmed,jasp...
# 1     Manav,Adarsh gupta,Sundeep,S.Sayeed Ahmed,jasp...
# 2     Manav,Adarsh gupta,Sundeep,S.Sayeed Ahmed,jasp...
# 3     ArdKn,Nirbhay kumar,Sagar Viswanathan,Asp,Plac...
# 4     ArdKn,Nirbhay kumar,Sagar Viswanathan,Asp,Plac...
# ...                                                 ...
# 1732  Prabha ds,Raghuram bk,Real Deal,Amazon Custome...
# 1733  Manu Bhai,Naveenpittu,Evatira Sangma,JAGANNADH...
# 1734  Nehal Desai,Danish Parwez,Amazon Customer,Amaz...
# 1735  Shubham Dubey,E.GURUBARAN,Mayank S.,eusuf khan...
# 1736  Rajib,Ajay B,Vikas Kahol,PARDEEP,Anindya Prama...
#
#                                               review_id  \
# 0     R3HXWT0LRP0NMF,R2AJM3LFTLZHFO,R6AQJGUP6P86,R1K...
# 1     R3HXWT0LRP0NMF,R2AJM3LFTLZHFO,R6AQJGUP6P86,R1K...
# 2     R3HXWT0LRP0NMF,R2AJM3LFTLZHFO,R6AQJGUP6P86,R1K...
# 3     RGIQEG07R9HS2,R1SMWZQ86XIN8U,R2J3Y1WL29GWDE,RY...
# 4     RGIQEG07R9HS2,R1SMWZQ86XIN8U,R2J3Y1WL29GWDE,RY...
# ...                                                 ...
# 1732  R3G3XFHPBFF0E8,R3C0BZCD32EIGW,R2EBVBCN9QPD9R,R...
# 1733  R3DDL2UPKQ2CK9,R2SYYU1OATVIU5,R1VM993161IYRW,R...
# 1734  R1TLRJVW4STY5I,R2O455KRN493R1,R3Q5MVGBRIAS2G,R...
# 1735  R39Q2Y79MM9SWK,R3079BG1NIH6MB,R29A31ZELTZNJM,R...
# 1736  R20RBRZ0WEUJT9,ROKIFK9R2ISSE,R30EEG2FNJSN5I,R2...
#
#                                            review_title  \
# 0     Satisfied,Charging is really fast,Value for mo...
# 1     Satisfied,Charging is really fast,Value for mo...
# 2     Satisfied,Charging is really fast,Value for mo...
# 3     A Good Braided Cable for Your Type C Device,Go...
# 4     A Good Braided Cable for Your Type C Device,Go...
# ...                                                 ...
# 1732  Received the product without spanner,Excellent...
# 1733  ok,everything was good couldn't return bcoz I ...
# 1734  very good,Work but front melt after 2 month,Go...
# 1735  Fan Speed is slow,Good quality,Good product,go...
# 1736  Works perfect,Ok good product,Nice Product. Re...
#
#                                          review_content  \
# 0     Looks durable Charging is fine tooNo complains...
# 1     Looks durable Charging is fine tooNo complains...
# 2     Looks durable Charging is fine tooNo complains...
# 3     I ordered this cable to connect my phone to An...
# 4     I ordered this cable to connect my phone to An...
# ...                                                 ...
# 1732  I received product without spanner,Excellent p...
# 1733  ok,got everything as mentioned but the measuri...
# 1734  plastic but cool body ,u have to find sturdy s...
# 1735  I have installed this in my kitchen working fi...
# 1736  It does it job perfectly..only issue is temp c...
#
#                     order_timestamp  \
# 0     2023-01-01 00:00:00.000000000
# 1     2023-01-01 00:00:00.000000000
# 2     2023-01-01 00:00:00.000000000
# 3     2023-01-01 05:58:01.967213114
# 4     2023-01-01 05:58:01.967213114
# ...                             ...
# 1732  2023-12-30 00:07:52.131147540
# 1733  2023-12-30 06:05:54.098360656
# 1734  2023-12-30 12:03:56.065573772
# 1735  2023-12-30 18:01:58.032786884
# 1736  2023-12-31 00:00:00.000000000
#
#                                            product_name  \
# 0     Wayona Nylon Braided USB to Lightning Fast Cha...
# 1     Wayona Nylon Braided USB to Lightning Fast Cha...
# 2     Wayona Nylon Braided USB to Lightning Fast Cha...
# 3     Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 4     Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# ...                                                 ...
# 1732  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 1733  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 1734  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 1735  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 1736  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#                    category  discounted_price  ...  rating_filled  \
# 0     Computers&Accessories             399.0  ...            4.2
# 1     Computers&Accessories             399.0  ...            4.2
# 2     Computers&Accessories             399.0  ...            4.2
# 3     Computers&Accessories             199.0  ...            4.0
# 4     Computers&Accessories             199.0  ...            4.0
# ...                     ...               ...  ...            ...
# 1732           Home&Kitchen             379.0  ...            4.0
# 1733           Home&Kitchen            2280.0  ...            4.1
# 1734           Home&Kitchen            2219.0  ...            3.6
# 1735           Home&Kitchen            1399.0  ...            4.0
# 1736           Home&Kitchen            2863.0  ...            4.3
#
#             category_filled  calculated_discount_filled contains_durable  \
# 0     Computers&Accessories                   63.694268             True
# 1     Computers&Accessories                   63.694268             True
# 2     Computers&Accessories                   63.694268             True
# 3     Computers&Accessories                   42.979943             True
# 4     Computers&Accessories                   42.979943             True
# ...                     ...                         ...              ...
# 1732           Home&Kitchen                   58.759521            False
# 1733           Home&Kitchen                   25.123153            False
# 1734           Home&Kitchen                   27.954545            False
# 1735           Home&Kitchen                   25.978836            False
# 1736           Home&Kitchen                   22.411924            False
#
#      product_qid week_number  day_name  year month     month_year
# 0     1672909124          52    Sunday  2023     1   January 2023
# 1     1672895755          52    Sunday  2023     1   January 2023
# 2     1672902996          52    Sunday  2023     1   January 2023
# 3     1672909124          52    Sunday  2023     1   January 2023
# 4     1672895755          52    Sunday  2023     1   January 2023
# ...          ...         ...       ...   ...   ...            ...
# 1732  1672923617          52  Saturday  2023    12  December 2023
# 1733  1672923617          52  Saturday  2023    12  December 2023
# 1734  1672923617          52  Saturday  2023    12  December 2023
# 1735  1672923617          52  Saturday  2023    12  December 2023
# 1736  1672923617          52    Sunday  2023    12  December 2023
#
# [1737 rows x 30 columns]

# %%
#univariate analysis, numeric variable

df['rating'].head()
# Out:
# 0    4.2
# 1    4.2
# 2    4.2
# 3    4.0
# 4    4.0
# Name: rating, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1737 entries, 0 to 1736
# Data columns (total 30 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  1737 non-null   object
#  1   user_id                     1737 non-null   object
#  2   user_name                   1737 non-null   object
#  3   review_id                   1737 non-null   object
#  4   review_title                1737 non-null   object
#  5   review_content              1737 non-null   object
#  6   order_timestamp             1737 non-null   object
#  7   product_name                1737 non-null   object
#  8   category                    1724 non-null   object
#  9   discounted_price            1724 non-null   float64
#  10  actual_price                1729 non-null   float64
#  11  rating                      1717 non-null   float64
#  12  rating_count                1735 non-null   float64
#  13  about_product               1737 non-null   object
#  14  img_link                    1737 non-null   object
#  15  product_link                1737 non-null   object
#  16  review_title_uppercase      1737 non-null   object
#  17  calculated_discount         1716 non-null   float64
#  18  price_range                 1727 non-null   object
#  19  rating_category             1717 non-null   object
#  20  rating_filled               1737 non-null   float64
#  21  category_filled             1737 non-null   object
#  22  calculated_discount_filled  1737 non-null   float64
#  23  contains_durable            1737 non-null   bool
#  24  product_qid                 1737 non-null   int64
#  25  week_number                 1737 non-null   int64
#  26  day_name                    1737 non-null   object
#  27  year                        1737 non-null   int64
#  28  month                       1737 non-null   int64
#  29  month_year                  1737 non-null   object
# dtypes: bool(1), float64(7), int64(4), object(18)
# memory usage: 395.4+ KB

# %%
plt.figure(figsize=(15,5))
sns.histplot(data = df, x='rating', color = "red")
mean_rating = df['rating'].mean()
plt.axvline(mean_rating, color = "blue", linestyle = "--", linewidth = 4)
plt.title(" Histogram of ratings", fontsize = 16)
plt.xlabel("Rating")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.hist(df['rating'], bins = 10, color = "skyblue")
plt.axvline(mean_rating, color = "blue", linestyle = "--", linewidth = 4)

# %%
#bar chart

sns.countplot(data = df, x = 'category', color = "violet")
plt.xticks(rotation = 90)
plt.xlabel("Categories of products")
plt.ylabel("counts")
plt.title("Bar Chart of Category")
plt.show()

# %%
#matplotlib
categories = df['category'].value_counts()

plt.figure(figsize=(8, 6))
plt.bar(categories.index, categories.values, color='skyblue')
plt.xticks(rotation=45)
plt.title("Count of Products by Category")
plt.xlabel("Category")
plt.ylabel("Count")
plt.show()

# %%
#bi variate scatter plot
sns.scatterplot(data = df, x = 'discounted_price', y = 'rating', color = "orange", alpha = 0.8)
plt.title("Scatter Plot of Discounted Price vs Rating")
plt.xlabel("Discounted Price", fontsize = 12)
plt.ylabel("Rating")
plt.show()

# %%
# two variable one time
import pandas as pd
import matplotlib.pyplot as plt

# Group by 'month_year' and calculate average rating
monthly_rating = df.groupby('month_year')['rating_filled'].mean().reset_index()

# Ensure 'month_year' is in datetime format
monthly_rating['month_year'] = pd.to_datetime(monthly_rating['month_year'], format='%B %Y')

# Sort the DataFrame based on 'month_year'
monthly_rating = monthly_rating.sort_values('month_year')

# Convert back to string for proper x-axis labels
monthly_rating['month_year'] = monthly_rating['month_year'].dt.strftime('%B %Y')

# Plot
plt.figure(figsize=(10, 6))
plt.plot(monthly_rating['month_year'], monthly_rating['rating_filled'], marker='o', color='navy')

# Rotate the x-axis labels and add a grid
plt.xticks(rotation=45)
plt.grid(True, linestyle='--', alpha=0.7)

plt.title("Average Rating by Month-Year", fontsize=16)
plt.xlabel("Month-Year", fontsize=12)
plt.ylabel("Average Rating", fontsize=12)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=df, x='category', y='rating', palette='Set3') # Styling Tip 💡 palette

plt.xticks(rotation=45)
plt.title("Rating Distribution by Category", fontsize=16)
plt.xlabel("Category", fontsize=12)
plt.ylabel("Rating", fontsize=12)
plt.show()
